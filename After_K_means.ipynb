# %% [markdown]
# ### GREY WOLF

# %%
import numpy as np

# Define your optimization function with variables as a closure
def create_cost_function(power_values, price_signal):
    def cost_function(variables):
        # Calculate the cost for each row separately
        costs = np.sum(power_values * price_signal * variables, axis=1)

        # Return the total cost
        return np.sum(costs)

    return cost_function

# Grey Wolf Optimization
def grey_wolf_optimization(power_values, price_signal, population_size, num_generations):
    # Initialization
    alpha, beta, delta = np.random.rand(population_size, 48), np.random.rand(population_size, 48), np.random.rand(population_size, 48)

    # Create the cost function with power_values and price_signal as closures
    cost_function = create_cost_function(power_values, price_signal)

    for generation in range(num_generations):
        # Calculate fitness values
        fitness_alpha, fitness_beta, fitness_delta = cost_function(alpha), cost_function(beta), cost_function(delta)

        # Update alpha, beta, and delta based on fitness values
        # (Code for updating alpha, beta, and delta)
        alpha = np.clip(alpha, 0, .3581)
        beta = np.clip(beta, 0, .3581)
        delta = np.clip(delta, 0, .3581)

    # Find the best solution
    best_solution = alpha[np.argmin(fitness_alpha)]

    return best_solution

# Example usage
price_signal = np.array([11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 3.99,
                         3.99, 3.99, 3.99, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 67.2,
                         67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 11.76, 11.76,
                         11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76])

power_values = np.array([0.5445, 0.3015, 0.3005, 0.3245, 0.319, 0.3225, 0.3575, 0.336, 0.161, 0.4475,
          0.156, 0.446, 0.474, 0.156, 0.4945, 0.8685, 0.5925, 0.4445, 0.421, 0.4195,
          0.4125, 0.4085, 0.3625, 0.4545, 0.2145, 0.2825, 0.298, 0.253, 0.2855, 0.2915,
          0.248, 0.406, 0.408, 0.544, 0.5825, 0.61, 0.664, 0.7215, 0.7005, 0.7745, 0.928,
          0.6555, 0.603, 0.519, 0.4425, 0.2095, 0.389, 0.346])

optimal_solution = grey_wolf_optimization(power_values, price_signal, population_size=1, num_generations=100000)

print("Optimal Solution:", optimal_solution)
# Out:
# Optimal Solution: [0.06196608 0.11891095 0.3581     0.296681   0.3581     0.20829763
#  0.21455411 0.20956722 0.00503135 0.3581     0.3581     0.3581
#  0.3581     0.3581     0.06952656 0.3581     0.3581     0.09549082
#  0.3581     0.25320626 0.3581     0.3581     0.3581     0.17291044
#  0.3581     0.3581     0.24101822 0.3581     0.0076307  0.3581
#  0.3581     0.3581     0.3581     0.33873414 0.3581     0.3581
#  0.3581     0.3581     0.3581     0.0966746  0.3581     0.3581
#  0.3581     0.3581     0.3581     0.3581     0.3581     0.3581    ]

# %% [markdown]
# # WHALE

# %%
import numpy as np

# Define your optimization function with variables as a closure
def create_cost_function(power_values, price_signal):
    def cost_function(variables):
        # Calculate the cost for each row separately
        costs = np.sum(power_values * price_signal * variables, axis=1)

        # Return the total cost
        return np.sum(costs)

    return cost_function

# Whale Optimization
def whale_optimization(power_values, price_signal, population_size, num_generations):
    # Initialization
    whales = np.random.rand(population_size, 48)

    # Create the cost function with power_values and price_signal as closures
    cost_function = create_cost_function(power_values, price_signal)

    for generation in range(num_generations):
        # Calculate fitness values
        fitness_whales = cost_function(whales)

        # Update whales based on fitness values
        # (Code for updating whales)
        whales = np.clip(whales, 0, 0.3581)

    # Find the best solution
    best_solution = whales[np.argmin(fitness_whales)]

    return best_solution

# Example usage
price_signal = np.array([11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 3.99,
                         3.99, 3.99, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2,
                         67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2,
                         67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2])
power_values = np.array([0.5445, 0.3015, 0.3005, 0.3245, 0.319, 0.3225, 0.3575, 0.336, 0.161, 0.4475,
          0.156, 0.446, 0.474, 0.156, 0.4945, 0.8685, 0.5925, 0.4445, 0.421, 0.4195,
          0.4125, 0.4085, 0.3625, 0.4545, 0.2145, 0.2825, 0.298, 0.253, 0.2855, 0.2915,
          0.248, 0.406, 0.408, 0.544, 0.5825, 0.61, 0.664, 0.7215, 0.7005, 0.7745, 0.928,
          0.6555, 0.603, 0.519, 0.4425, 0.2095, 0.389, 0.346])

optimal_solution = whale_optimization(power_values, price_signal, population_size=1, num_generations=100000)

print("Optimal Solution:", optimal_solution)
# Out:
# Optimal Solution: [0.13855196 0.31408855 0.3581     0.3581     0.31632033 0.3581
#  0.3581     0.3581     0.3581     0.3581     0.03965724 0.3581
#  0.13083325 0.3581     0.06361578 0.3581     0.3581     0.1724049
#  0.3581     0.3581     0.3581     0.3581     0.3581     0.03290685
#  0.3581     0.3581     0.3581     0.34500185 0.3581     0.3581
#  0.23380477 0.3581     0.00488923 0.3581     0.3581     0.3581
#  0.02811419 0.06661838 0.3581     0.3581     0.3581     0.3581
#  0.02378603 0.3581     0.29722494 0.3581     0.3581     0.30321325]

# %% [markdown]
# ###GA

# %%
import numpy as np

# Define your optimization function with variables as a closure
def create_cost_function(power_values, price_signal):
    def cost_function(variables):
        # Implement your cost function using the power values, price signal, and variables
        # Return the cost associated with the solution
        return np.sum(power_values * price_signal * variables)

    return cost_function

# Genetic Algorithm
def genetic_algorithm(power_values, price_signal, population_size, num_generations):
    # Initialization
    population = np.random.rand(population_size, 48) * .3581  # Randomly initialize population within constraint

    # Create the cost function with power_values and price_signal as closures
    cost_function = create_cost_function(power_values, price_signal)

    for generation in range(num_generations):
        # Evaluate fitness
        fitness_values = [cost_function(variables) for variables in population]

        # Selection
        selected_indices = np.argsort(fitness_values)[:population_size // 2]

        # Crossover
        crossover_points = np.random.randint(0, 2, size=(population_size // 2, 48), dtype=bool)
        offspring = population[selected_indices] * crossover_points + population[np.roll(selected_indices, 1)] * ~crossover_points

        # Mutation
        mutation_rate = 0.1
        mutation_mask = np.random.rand(population_size // 2, 48) < mutation_rate
        mutation_values = np.random.rand(population_size // 2, 48)
        mutated_offspring = np.where(mutation_mask, mutation_values, offspring)

        # Apply constraints on power values
        mutated_offspring = np.clip(mutated_offspring, 0, .3581)

        # Combine parents and offspring
        population = np.vstack([population, mutated_offspring])

    # Find the best solution
    best_index = np.argmin(fitness_values)
    best_solution = population[best_index]

    return best_solution

# Example usage
# def genGA(power_values)
price_signal = np.array([11.76,11.76,11.76,11.76,11.76,11.76,11.76,11.76,11.76,11.76,11.76,3.99,
                         3.99,3.99,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,
                         67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2,
                         67.2,67.2,67.2,67.2,67.2,67.2,67.2,67.2])

power_values = np.array([0.5445, 0.3015, 0.3005, 0.3245, 0.319, 0.3225, 0.3575, 0.336, 0.161, 0.4475,
          0.156, 0.446, 0.474, 0.156, 0.4945, 0.8685, 0.5925, 0.4445, 0.421, 0.4195,
          0.4125, 0.4085, 0.3625, 0.4545, 0.2145, 0.2825, 0.298, 0.253, 0.2855, 0.2915,
          0.248, 0.406, 0.408, 0.544, 0.5825, 0.61, 0.664, 0.7215, 0.7005, 0.7745, 0.928,
          0.6555, 0.603, 0.519, 0.4425, 0.2095, 0.389, 0.346])

optimal_solution = genetic_algorithm(power_values, price_signal, population_size=1, num_generations=100000)

print("Optimal Solution:", optimal_solution)
# Out:
# Optimal Solution: [0.0308077  0.08529355 0.2126089  0.0168797  0.24644714 0.25602525
#  0.17152969 0.1352306  0.12485168 0.0349433  0.0313627  0.30449536
#  0.05778076 0.3287033  0.2795913  0.27736247 0.16545331 0.14665378
#  0.14384634 0.21944658 0.29204242 0.23875874 0.09562222 0.22483376
#  0.16473272 0.11000079 0.14488402 0.29264372 0.31542753 0.19087377
#  0.20449578 0.06321492 0.15348951 0.06470369 0.17092412 0.06350591
#  0.27928967 0.28783055 0.04715039 0.27923509 0.03185451 0.03214151
#  0.11727862 0.2424652  0.31137923 0.29288658 0.29648795 0.23970628]

# %% [markdown]
# ###Comparison with original cost

# %%
import numpy as np

price_signal = np.array([11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 3.99,
                         3.99, 3.99, 3.99, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 67.2,
                         67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 67.2, 11.76, 11.76,
                         11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76, 11.76])

# ORG
power_values1= np.array([0.5445, 0.3015, 0.3005, 0.3245, 0.319, 0.3225, 0.3575, 0.336, 0.161, 0.4475,
          0.156, 0.446, 0.474, 0.156, 0.4945, 0.5685, 0.5925, 0.4445, 0.421, 0.4195,
          0.4125, 0.4085, 0.3625, 0.4545, 0.2145, 0.2825, 0.298, 0.253, 0.2855, 0.2915,
          0.248, 0.406, 0.408, 0.544, 0.5825, 0.51, 0.564, 0.5215, 0.7505, 0.5745, 0.528,
          0.5555, 0.503, 0.519, 0.4425, 0.2095, 0.389, 0.346])

# GA
power_values2 = np.array([0.0308077, 0.08529355, 0.2126089, 0.0168797, 0.24644714, 0.25602525,
                    0.17152969, 0.1352306, 0.12485168, 0.0349433, 0.0313627, 0.30449536,
                    0.05778076, 0.3287033, 0.2795913, 0.27736247, 0.16545331, 0.14665378,
                    0.14384634, 0.21944658, 0.29204242, 0.23875874, 0.09562222, 0.22483376,
                    0.16473272, 0.11000079, 0.14488402, 0.29264372, 0.31542753, 0.19087377,
                    0.20449578, 0.06321492, 0.15348951, 0.06470369, 0.17092412, 0.06350591,
                    0.27928967, 0.28783055, 0.04715039, 0.27923509, 0.03185451, 0.03214151,
                    0.11727862, 0.2424652, 0.31137923, 0.29288658, 0.29648795, 0.23970628]
)

# WHALE

power_values3 = np.array([0.13855196, 0.31408855, 0.3581, 0.3581, 0.31632033, 0.3581,
                    0.3581, 0.3581, 0.3581, 0.3581, 0.03965724, 0.3581,
                    0.13083325, 0.3581, 0.06361578, 0.3581, 0.3581, 0.1724049,
                    0.3581, 0.3581, 0.3581, 0.3581, 0.3581, 0.03290685,
                    0.3581, 0.3581, 0.3581, 0.34500185, 0.3581, 0.3581,
                    0.23380477, 0.3581, 0.00488923, 0.3581, 0.3581, 0.3581,
                    0.02811419, 0.06661838, 0.3581, 0.3581, 0.3581, 0.3581,
                    0.02378603, 0.3581, 0.29722494, 0.3581, 0.3581, 0.30321325])

#GREY
power_values4 = np.array([0.06196608, 0.11891095, 0.3581, 0.296681, 0.3581, 0.20829763,
                       0.21455411, 0.20956722, 0.00503135, 0.3581, 0.3581, 0.3581,
                       0.3581, 0.3581, 0.06952656, 0.3581, 0.3581, 0.09549082,
                       0.3581, 0.25320626, 0.3581, 0.3581, 0.3581, 0.17291044,
                       0.3581, 0.3581, 0.24101822, 0.3581, 0.0076307, 0.3581,
                       0.3581, 0.3581, 0.3581, 0.33873414, 0.3581, 0.3581,
                       0.3581, 0.3581, 0.3581, 0.0966746, 0.3581, 0.3581,
                       0.3581, 0.3581, 0.3581, 0.3581, 0.3581, 0.3581])
print('ORIGINAL')
result1 = price_signal * power_values1 * 0.5
print(result1)
total1=np.sum(result1)
total1 *= 64
print(total1)

print('GA')
result2 = price_signal * power_values2 * 0.5
print(result2)
total2=np.sum(result2)
total2 *= 64
print(total2)

print('WHALE')
result3 = price_signal * power_values3 * 0.5
print(result3)
total3=np.sum(result3)
total3 *= 64
print(total3)

print('GREY WOLF')
result4 = price_signal * power_values4 * 0.5
print(result4)
total4=np.sum(result4)
total4 *= 64
print(total4)
# Out:
# ORIGINAL
# [ 3.20166    1.77282    1.76694    1.90806    1.87572    1.8963
#   2.1021     1.97568    0.94668    2.6313     0.91728    0.88977
#   0.94563    0.31122    0.9865275  3.34278    3.4839     2.61366
#   2.47548    2.46666    2.4255     2.40198    2.1315     2.67246
#   1.26126    9.492     10.0128     8.5008     9.5928     9.7944
#   8.3328    13.6416    13.7088    18.2784    19.572     17.136
#  18.9504    17.5224     4.41294    3.37806    3.10464    3.26634
#   2.95764    3.05172    2.6019     1.23186    2.28732    2.03448  ]
# 16144.95792
# GA
# [ 0.18114928  0.50152607  1.25014033  0.09925264  1.44910918  1.50542847
#   1.00859458  0.79515593  0.73412788  0.2054666   0.18441268  0.60746824
#   0.11527262  0.65576308  0.55778464  1.63089132  0.97286546  0.86232423
#   0.84581648  1.29034589  1.71720943  1.40390139  0.56225865  1.32202251
#   0.96862839  3.69602654  4.86810307  9.83282899 10.59836501  6.41335867
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

optimal_solution_1 = np.array([0.18114928, 0.50152607, 1.25014033, 0.09925264, 1.44910918, 1.50542847,
                               1.00859458, 0.79515593, 0.73412788, 0.2054666, 0.18441268, 0.60746824,
                               0.11527262, 0.65576308, 9.39426768, 9.31937899, 5.55923122, 4.92756701,
                               4.83323702, 7.37340509, 9.81262531, 8.02229366, 3.21290659, 7.55441434,
                               5.53501939, 3.69602654, 4.86810307, 9.83282899, 10.59836501, 6.41335867,
                               6.87105821, 2.12402131, 5.15724754, 2.17404398, 5.74305043, 2.13379858,
                               9.38413291, 9.67110648, 1.5842531, 9.38229902, 1.07031154, 1.07995474,
                               3.94056163, 8.14683072, 10.46234213, 9.84098909, 9.96199512, 8.05413101])

optimal_solution_2 = np.array([3.20166, 1.77282, 1.76694, 1.90806, 1.87572, 1.8963, 2.1021, 1.97568,
                               0.94668, 2.6313, 0.91728, 0.88977, 0.94563, 0.31122, 16.6152, 29.1816,
                               19.908, 14.9352, 14.1456, 14.0952, 13.86, 13.7256, 12.18, 15.2712,
                               7.2072, 9.492, 10.0128, 8.5008, 9.5928, 9.7944, 8.3328, 13.6416,
                               13.7088, 18.2784, 19.572, 20.496, 22.3104, 24.2424, 23.5368, 26.0232,
                               31.1808, 22.0248, 20.2608, 17.4384, 14.868, 7.0392, 13.0704, 11.6256])

optimal_solution_3 = np.array([0.81468552, 1.84684067, 2.105628, 2.105628, 1.85996354, 2.105628, 2.105628,
                               2.105628, 2.105628, 2.105628, 0.23318457, 0.7144095, 0.26101233, 0.7144095,
                               2.13749021, 12.03216, 12.03216, 5.79280464, 12.03216, 12.03216, 12.03216,
                               12.03216, 12.03216, 1.10567016, 12.03216, 12.03216, 12.03216, 11.59206216,
                               12.03216, 12.03216, 7.85584027, 12.03216, 0.16427813, 12.03216, 12.03216,
                               12.03216, 0.94463678, 2.23837757, 12.03216, 12.03216, 12.03216, 12.03216,
                               0.79921061, 12.03216, 9.98675798, 12.03216, 12.03216, 10.1879652])

optimal_solution_4 = np.array([0.78515193, 1.64247345, 2.105628, 2.105628, 2.105628, 2.105628, 2.105628,
                               2.105628, 2.105628, 2.105628, 2.105628, 0.7144095, 0.7144095, 0.27967574,
                               12.03216, 12.03216, 1.97268288, 10.81827802, 12.03216, 12.03216, 0.06715464,
                               1.57595424, 10.6132656, 12.03216, 12.03216, 9.21448517, 12.03216, 12.03216,
                               6.339648, 8.24059152, 1.19416315, 5.80067678, 1.08008611, 12.03216, 12.03216,
                               6.58434437, 12.03216, 8.63268403, 6.46171848, 3.8204796, 12.03216, 12.03216,
                               6.33217603, 12.03216, 10.03373045, 6.80238922, 12.03216, 11.10840494])

# Smoothing out optimal_solution_1 using a moving average filter
window_size = 5
optimal_solution_1_smoothed = np.convolve(optimal_solution_1, np.ones(window_size)/window_size, mode='valid')
optimal_solution_3_smoothed = np.convolve(optimal_solution_3, np.ones(window_size)/window_size, mode='valid')
optimal_solution_4_smoothed = np.convolve(optimal_solution_4, np.ones(window_size)/window_size, mode='valid')

# Plot the solutions
plt.figure(figsize=(10, 5))
plt.plot(optimal_solution_1_smoothed, label='Genetic Algo')
plt.plot(optimal_solution_2, label='Original One')
plt.plot(optimal_solution_3_smoothed, label='Whale Optimization')
plt.plot(optimal_solution_4_smoothed, label='Grey Wolf Optimization')
plt.xlabel('Time Step')
plt.ylabel('Power')
plt.title('Optimal Solutions')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the data
methods = ['Genetic Algorithm', 'Original', 'Grey Wolf', 'Whale Optimization']
costs = [14529.7935171648, 36435.78624, 20496.7734627264, 22446.635222793597]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(methods, costs, color=['blue', 'orange', 'green', 'red'])

# Add labels and title
plt.xlabel('Optimization Method')
plt.ylabel('Cost')
plt.title('Comparison of Optimization Methods')

# Show plot
plt.show()
